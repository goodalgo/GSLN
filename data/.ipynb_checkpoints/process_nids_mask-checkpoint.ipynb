# %%
import dgl
from dgl.data.utils import load_graphs,save_graphs

# %%
g = dgl.DGLGraph()
# Out:
# /home/pai/lib/python3.6/site-packages/dgl/base.py:45: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   return warnings.warn(message, category=category, stacklevel=1)

# %%
import pandas as pd
import numpy as np

# %%
# df_ori = pd.read_csv('ndatas/node_feat_sigir_preload_multi.csv', header=0, sep='\t', error_bad_lines=False)
df_ori= pd.read_csv('ndatas/node_feat_sigir.csv', header=0, sep='\t',dtype={'node_ori_id': str}, error_bad_lines=False)

print(df_ori)
# Out:
#         node_id          node_ori       node_ori_id deg_sum  \
# 0             0       1.19122e+18                 -       -
# 1             1       1.18073e+18                 -       -
# 2             2       1.18072e+18                 -       -
# 3             3       8.19417e+15  8194171387534752       2
# 4             4       1.18072e+18                 -       -
# ...         ...               ...               ...     ...
# 149853   149853  2416207138512341  2416207138512341       1
# 149854   149854  3205612664515960  3205612664515960       1
# 149855   149855  2902133261030891  2902133261030891       1
# 149856   149856  6231947145800878  6231947145800878       1
# 149857   149857  7433081876149126  7433081876149126       1
#
#                                                     title  \
# 0                                                       -
# 1                                                       -
# 2                                                       -
# ...

# %%
nlist = ["8325231995309070", "1104441079030696", "8941308762467171", "1984996738116473", "944262488956787", "3825921299095254", "1371584594406157", "6900478482308337", "1342595430300245", "966477767802531", "2162038249273964", "1202573273152562", "7008006537775728", "8766939718664052", "2442434836465353", "6492683982929069", "4524159442685568", "7360865552737484", "3594804864951055", "7032546991738354", "6829921195501853", "1803137569494852", "5897562980294474", "1685883677479653", "3151917693310619", "1261087883737903", "523130230910347", "5465243102940498", "8047115346616692", "3553739691207771", "6558336793717274", "8316705709498179", "5110776065466170", "4241432108159762", "1232993867221363", "1923487898224837", "3678811029968952", "4685119222058435", "3400813910205712", "3107811651010387", "3906861858090085", "4921603248346273", "8256766258060729", "2557658444544844", "151170583372984", "2286312742390870", "7956576591088847", "3209154028945593", "3874267898589038", "5306174709031121", "109855939353305", "9445302483472537", "4296588738329461", "8987844674638923", "2562743616154381", "9303761446420841", "9880503330279439", "5955896822842214", "7808184248488394", "8054549178961641", "9988487525744365", "5580615377251168", "7654067232451802", "2319840535378325", "8196814065730547", "9834857845764174", "402036319586781", "9040563859568306", "5168234312109753", "5052798803878546", "9969259609644447", "3619914146685836", "7348330081198315", "574908318679809", "5193741971339244", "8948521253802609", "5718929848890465", "6833280832258864", "7845246446502376", "6447619921995044", "7304050820203507", "4352855095737118", "9399671507803036", "8783975781987545", "1086678600159371", "6957348837087427", "8662092620296768", "8874763412624916", "6284530890737292", "5901452404856171", "607717795077363", "4039403317852781", "1624117055433388", "3703634418927228", "6070713777181700", "772920977523162", "5102802306343496", "511776575058789", "5088476877470204", "626288004830361", "2131537952359976", "8281169020322702", "8894947076729935", "2331019044609237", "1884544857465751", "6836487330950155", "3861173066900041", "3214808394452415", "3182224598217282", "6009035308015874", "5625572554657735", "6505983281997149", "5154858551598504", "6854426116719633", "6849692325947506", "3713891720120036", "94187403402061", "4204919393292611", "7935088789469942", "7285149191866233", "400298327166852", "2357516935365952", "8289225131526607", "893906759490521", "9838548944814273", "9793943708258335", "3370884757862876", "8183017075886052", "1529923037736781", "7270544663654763", "8898876722377485", "4595466776127302", "5281234711491439", "8349691236611373", "1473278415849234", "9129250252319430", "4121741571429202", "2734303281838882", "9147285292407728", "7444610700110400", "8392212207265442", "6777532319858998", "9608764640347533", "3129294823552355", "7023540649699151", "2082239842392199", "4831807401458152", "7415447293823852", "2401769860633771", "9987211142390000", "8925990622006475", "9200327429512487", "110928261040465", "5977148528172770", "658979363671025", "6746678376546674", "2946681927082066", "1542150296588464", "3153021293725152", "7134322619282186", "3523241856072021", "9031309573576241", "3761890399031130", "4174181060568758", "2053197222185631", "385416768960264", "4886560798550414", "8979441988734350", "7747699766850683", "3921987506740242", "6477451214741300", "1642065764008534", "1029126983184247", "3482905676517536", "9217495101006179", "965541728907278", "655324234743815", "1873793041311935", "6644919731842", "3295042302263024", "9758351541675639", "6125239431194340", "8576952139030045", "7582752624718983", "3273224392261151", "7412369230337893", "2954527492378516", "5242931491939825", "4451851574889078", "7768464137803036", "1903373157787287", "3578340632815256", "1986334023683543", "7329876729482613", "1005898132692711", "7706226262954412", "6121750414865350", "7738847115946653", "1460938295780507", "7134972944608328", "8904647185786072", "9963865775260771", "1524275045450806", "9817517336927496", "4177822378013110", "7210307331849122", "2051182896203769", "1716746033953776", "9917493404196594", "5632027258392411", "2075803278511076", "3326111984596652", "2527360343164348", "7657375656276732", "7754774363917183", "5735789608598747", "5974534354878798", "8595340825295943", "7151204158196931", "8201747959977604", "5993987372649974", "8616820894697687", "114782013559647", "6973170632992666", "9044268060035045", "1289504042932545", "7748184013449569", "2628753923182053", "6438865583771410", "557094659971545", "9073202427513102", "8810141860037320", "2048187168915118", "2242916514280664", "9698865495072529", "5419196590777340", "6770232872950210", "8056349622757488", "4401768127840878", "3558228991555412", "385760256801816", "750252563526801", "9251097969490345", "2661981380619981", "8596407995875257", "5914762132791115", "3561405917798028", "679709241833899", "7124288910798237", "7316815301258989", "7854911599142121", "9754215292327317", "5934943506334682", "8513345952277968", "2159756324077738", "8269316599617412", "3823905520966033", "2599044819267001", "1473644673173769", "6060323377984472", "8079042565421966", "7624780729647371", "8371606852942548", "7346824221625265", "2820293944498410", "7100299116157905", "4037858386172322", "8109991141081760", "310886315819757", "7823008891140718", "7166511994140972", "9542863463949012", "5888957199017627", "2053384636982352", "2789708873924417", "7204600257351797", "1381342013661664", "3947402447885849", "594031985092772", "8569698519229293", "8136790312839854", "1241984540333779", "3364012799597589", "277926612548407", "9345047894210276", "3932415817550561", "5587607084346879", "9971932535833678", "5727382363010500", "4853603638176042", "7569044502827261", "8178120160465451", "3753010685629602", "2709071349074507", "8406558100996282", "4633507940346496", "8549911267915371", "8460692857397965", "1170634359958992", "9060363018219945", "5044669392687567", "7925622036674022", "6669324133859457", "3449501531378256", "7381465858293644", "6132003020856695", "197341411431336", "1672714371781646", "690387833013769", "5562615722879838", "450305139238670", "9917720452644284", "9395514345257029", "3599585903030557", "7794944604322063", "2996041195873871", "906385510295269", "7726329526829375", "304934076944776", "134453157031251", "936036538230240", "4571654693528392", "9081756026353005", "921526224577889", "3536480498398620", "4059475986280512", "492043434901752", "5223321023253408", "9054558880214611", "1632980768782931", "5481573488299950", "5799087047325489", "9566163335489641", "2410364328486311", "8316877472408670", "413794057725534", "1342459325432779", "2787405313796693", "4192452828687343", "9278254479726326", "3417438659365136", "3483190110672069", "8004776645799442", "5017315373868918", "8558177377080813", "9202500602580432", "2072517736526064", "6074079769017693", "9595075613119131", "6778551200432707", "2211316767912800", "7604514697204578", "5204102384455867", "9189407566297010", "6882865411381330", "4983912103547745", "8471173981659799", "9123912179504476", "3911659829190754", "7332401014841046", "9443418325925381", "4544224817383399", "6376309084197270", "7493710071418652", "2893238220496090", "4723274191577181", "8995712645948196", "1129088225318504", "4647041076231581", "5580877128616179", "2254185801969413", "1627033038403329", "3157172599215788", "1745389761596275", "3298295985731398", "619328240268140", "950111096542528", "1055185102643943", "8334237591763752", "4892671915812977", "4880343634209142", "3103049992950526", "3017157207303460", "3907923076753351", "7579635340207419", "606842816683652", "9168022018140522", "5369483464670140", "3947366354201409", "1897814676288123", "9973689560892100", "1369639655591342", "4455590734378089", "6228585280175072", "6812229293348877", "5717999032593065", "2251584123531108", "4571374013017319", "5226084191603168", "771715329563639", "3091371807775377", "6258007856728694", "2354191801864544", "9287540285805390", "6865693741757271", "169495745436494", "1719988855294237", "8924807235913177", "2571446697187740", "9090048880657183", "7761284975552964", "5746372767364903", "3314238713973153", "9096210346764381", "5263741367152862", "7546933969797522", "5209253583631565", "7154132659925230", "2333589400269095", "7994152883964873", "2755529078368092", "1402516636110813", "6240991051566404", "7673731363898642", "6359288573176436", "21192187819361", "4656438127708260", "4032853318466560", "3016614830400160", "4163392713980700", "4044618010147810", "8359465214936366", "301871213328127", "6519585190465531", "8791872048772237", "4508843002645685", "6791486975432232", "3807254620285546", "4551915249126123", "3737393265039885", "2719904935173910", "2718607963909931", "6604092961606674", "279588894526441", "3561653327358504", "8266401570129101", "5588696020472846", "5031097701823928", "3845541947032927", "4108148603946855", "9708026354717345", "1409660044197273", "2383821695333384", "8185490264827931", "5133053200458994", "6077156818451276", "2176020970711414", "3833830387194695", "4915198672714828", "9926687036311185", "3512564064072725", "9300821609387698", "6821266928422913", "5530138782095371", "7775466350658646", "9871137330125692", "2486688053944471", "3433073792583274", "9065447106001490", "479476817665715", "3387455282703007", "2072822267868182", "7780450958540951", "3261261169284585", "9566671167763408", "3742014272742983", "4083440456083143", "4501675938656143", "2959533744243827", "7603597295125593", "9150472546843040", "5525887763174966", "3894493167063858", "9060364137603292", "2184030642856268", "7856463528871350", "4892535250827069", "1688553309663650", "7677163395000832", "3385704870739177", "4101567930233669", "2354423792357308", "5447831764291738", "9014516748561727", "1708696298009524", "9759968863589091", "7725085545625213", "8939867537992779", "8002814710967823", "9629026256896290", "7667606409008468", "9227600656374890", "4112361884452023", "4225758203331896", "1026920159181651", "7496392177534021", "8120863493304936", "502048911074190", "8548585892047517", "2817133208221059", "8318821413722978", "2018107734103790", "8442681149429145", "3249788237468515", "544103684173029", "3636664615576956", "9330858078309539", "5510497336724456", "5457670940939177", "4774911806341388", "9631155658770765", "5154356937376573", "8083310710372193", "2085365145826206", "8128110207694021", "8771172254908198", "503051036058083", "1738808401197805", "2387117455442489", "1473123552249997", "1534174176403265", "4624548753187242", "6313035599362025", "7502665500600465", "7580086359404416", "3833666235692861", "8474251080653936", "1833912763705062", "1368250120101732", "8127730575155265", "353454080388841", "5080946345246906", "3353422422115380", "9238027039874622", "4689524723766305", "7371581307750504", "8654270728546896", "1720223228284859", "9027404765967558", "3348884326314159", "2743936347115924", "4543628389224722", "6999033169656420", "6495314830670247", "2982833287360926", "6899057155049784", "2321625138923014", "9429575685784223", "4656803865128318", "3261859822836115", "6644621518225400", "5818740714263234", "7762366821018055", "2126864100295688", "4449936203352887", "2453071755394521", "9405104237012733", "8625282312214424", "4422531383795420", "8267846840040201", "5569097489237863", "701403151706438", "5830583501161403", "1557315004577260", "1589744694609919", "7749619352780105", "8519436154915465", "9046255713819388", "4146849775620288", "910303174947257", "441218182241273", "1966524288518564", "5449087217335157", "969233667934288", "1407160564499481", "6627891799679063", "9390719963570581", "3931423002984494", "5465206118942726", "5784098680465121", "9143805820693418", "1756850113275422", "4631433728481907", "1855447175000571", "5994473884805815", "9273538089711334", "3783083785701674", "3475575856398933", "5374433774226700", "2389932598761704", "1967549440465922", "8162869136816196", "4665110899387008", "2923068042451896", "6438256719551869", "182215472139322", "1189172727455889", "6269008168600735", "3150758661341796", "4352786945964362", "2131848943780209", "6696824686147153", "6728908694401418", "4275689790601713", "9762857816315683", "749301642036245", "9858533455753281", "17189286920553", "2830781644903829", "2052462083196840", "3817172354217645", "8488583865790265", "995120909941398", "9905037572101116", "6086441974977978", "5006914067173493", "5730982287768700", "4155949978285106", "358090171450989", "8134600114991914", "9423946086649837", "7588669733429131", "203181858316921", "6701959153422395", "2561947054598670", "1757363055269913", "8045232460727", "2625988707978616", "3960540929774599", "4168787844548249", "863804713877673", "890343472690816", "5033901979919493", "6688111305229009", "5373404334038389", "6984509125985504", "9471559903364535", "3180618800595106", "7567596249555315", "36871251535627", "2757694965568450", "6752862175391328", "7458007318848871", "1398925624487886", "5225905620667716", "2050708959726154", "3558636291725126", "5824015619649338", "8107344662260834", "8550637195163277", "2946302683820043", "3448559181251147", "3098311281023186", "1334075070816139", "7211396568974753", "3014341200621727", "84060623196700", "3909855494726490", "6235527291387843", "6268393366212227", "8655799867350303", "1534497470748709", "3812917401933249", "2932349008753196", "3615700567490188", "7345265866005468", "8404236813848433", "5391608505610966", "7769714223953493", "8562138848786688", "3827208310720811", "2541929097394488", "1782884491398478", "7771006966277487", "2246861951570480", "4653079731906683", "6730433300848742", "3940594726603542", "348127330030042", "227677927061671", "4000278035955529", "9875240507450480", "1599546210676753", "995736565041249", "7692347727452009", "924795217474285", "9295902412295815", "8130915065926492", "1796949712285696", "4756029158321204", "1092110149774447", "5307719849159273", "6291958557719004", "1528814731398486", "2915045159924603", "1383898139329235", "9892143397214469", "2323042491720148", "9206216222091264", "2259988659929688", "7470077998709640", "9074940276255245", "9818039433288474", "8262259909508624", "3618357721638302", "9210035966209092", "7064455774127013", "1384195577039530", "1633910577713538", "8174679829618320", "7924493904495304", "6175588092400432", "968896722870276", "2533310094290980", "8051618247399425", "6789245980639122", "1479254979358666", "5869675957111784", "6447017489429024", "7781564211962446", "8399656994329921", "2641445674463209", "3242429416385818", "4448893799332471", "4629936328648355", "7197318256281425", "7276784429307813", "2192055047343423", "5282004086300911", "364505207370426", "5256713350186145", "9723901155059469", "3645932173804497", "4102129757136877", "3354437068397655", "3915778903199173", "427935461938545", "2211339145233042", "5050830826445747", "2081121141425948", "5711097295965660", "8546641787912736", "2761552821096904", "8172051555798576", "2539263210206710", "1768028760476178", "1436890822306436", "5171422457929782", "2393270273979770", "4975573574878923", "1791905699418650", "3440628843966701", "126272255613135", "1675463338069071", "7433380911398709", "5664114162919449", "7311753120078094", "6205393076345405", "1061725044450695", "3751441687271260", "6681862261482759", "5856377449939517", "9367143062379634", "3681148927667232", "7802992608746890", "9220530809677885", "1146056535222773", "3267681579608435", "911317555279926", "9566405980332220", "8953564119973724", "8091479456944978", "8380983335018070", "1517763878326165", "7315947513880069", "5436835969748906", "3747218484832882", "3904350938257983", "6230887613446260", "7554347499858195", "9011641453229759", "3263601514715439", "9037481996885248", "5951705343912899", "2102523907138008", "4513773338938212", "7863577639952734", "2697246885985546", "5405918833238453", "985839601137657", "2963412640358724", "8773105200045556", "371108658111206", "3997366771842201", "6882020614497336", "2560089457830990", "3077089583019423", "3260885344497606", "677950482331169", "4137513900730465", "7488282650855151", "4723503822855266", "6903881732327505", "5258169001627805", "5168570873503156", "8890909118217018", "741172607029624", "8946541427664505", "4102044447550709", "5418514364205186", "192975361006973", "4567357732888116", "7330075754877494", "1462800803281923", "3623305960001495", "3129045190433728", "4161119523760881", "9284161214339045", "2274999918934036", "3607384605810439", "8086606842888168", "2557616674461247", "1257358743242216", "7929002422107315", "648756036611203", "2826002690248153", "5234871402023632", "3068937748021894", "976525043709514", "3408447315708886", "9984141704368425", "4626859023549417", "6721914118548322", "2731688996823418", "2559374196957945", "98791694757055", "6287462198934662", "346244926502519", "2737818872251544", "8409960924539547", "9622390651738378", "4938437769891392", "6444609910316384", "4995722928348592", "4383884181553424", "6743279820298422", "8142410080709986", "910246154561290", "3308067992301119", "4659548085711517", "6533223216164689", "6192629136667430", "9292535734623444", "2456946539495473", "4008951296916982", "1546098714762981", "9663448485223421", "1222971484411593", "7884532008920206", "274556823217780", "5585041771969112", "6895891000121855", "9931473126996035", "5421105714884235", "3309358208642719", "5422013159611785", "6658454758059029", "1372186390295506", "5756513608414840", "5985776674710472", "2768694773725987", "9952976101813304", "8931886713588674", "3465621331757040", "7951005554896013", "2595756611309827", "1960689817369450", "9433571348012114", "1329841337071729", "749534175752193", "3907259502430676", "6547230481787949", "317042081343446", "7673966240412846", "2230823711823230", "4094290508943608", "445228955883423", "1689260597936678", "9396968608006766", "9200890007634143", "3635197438495855", "3405729452777949", "3108224846653440", "6640758464943693", "3652584414410164", "1898294569353235", "9459579135684578", "8475567218952235", "1761315043114854", "9638390036911306", "2442553719195640", "536261211341370", "3620666153730139", "7129422339839349", "2275935476623290", "2608549785359521", "5093382473603785", "17791394152878", "7802022144466518", "786507194969678", "2182974276842662", "5861843100050812", "1458158138339316", "6954838615977093", "7890379339678930", "9686641587039964", "9402005995168417", "2815254460992628", "3408878155293078", "5173266216119047", "5732442498980212", "604426407555774", "3235095023684197", "842397057859455", "2702421443472747", "4613001723073490", "6903447355939339", "3089035535335882", "8161449704817046", "5656133919694097", "8039632226562302", "5402244994956936", "6332418958084294", "4544377824194554", "1843892246690372", "8147404016766905", "1805598339785290", "8080512570790428", "9222322539411929", "9401965493436659", "6370885085810430", "1531225088085052", "9543818691366955", "7865332615091260", "8551642188748236", "8540712319256091", "2316336687216153", "3666843057897192", "9795790454886000", "8150401801301265", "7982983037742039", "1881130710665416", "1046207807096082", "9514238532993174", "7509535756807629", "9435982385370193", "8967628139702265", "5433573902511297", "722524843612752", "146867309436823", "409960512864185", "8871929812827289", "4322184059350050", "3325176643188343", "8912577686148390", "7788392523837966", "9708029197168909", "2121898307085164", "9643892735740075", "2053994467977022", "9777128057981654", "4896526350885369", "3428651783750610", "7593948958344532", "3686102318015149", "4337058804267361", "3247844968938279", "912655057012002", "7285112880688259", "6153871804766140", "2705886582795567", "9864166993050483", "9800773006589691", "8394061272520448", "7185553047560673", "1759260957098656", "8291514447650345", "9663352616500133", "9972301257822361", "916865644075167", "2253347356349010", "5243269474562552", "3685552688128479", "4009689152662407", "2142407788522173", "9461127660799195", "5253456458370634", "8733872799259461", "6032875054380263", "6459263180273419", "9829517142231184", "4576101965893373", "4968641402119422", "1273639561925032", "360011895998125", "5840284169001561", "1289467052435775", "9387956856244578", "5127034788909337", "1788678455143789", "7345873521537126", "4719244822760735", "6317947691472677", "8744595194261629", "4285848472140017", "8514685804245131", "4655879352794667", "1696548987019131", "6828103917155823"]

sample_df = df_ori[df_ori['news_code'].isin(nlist)]
print(sample_df.count())
# Out:
#         node_id          node_ori       node_ori_id deg_sum  \
# 379         379       5.30617e+15  5306174709031121       1
# 662         662       9.68897e+14   968896722870276       1
# 1213       1213       6.64462e+15  6644621518225400       1
# 1414       1414       1.05519e+15  1055185102643943       1
# 1496       1496       1.96069e+15  1960689817369450       1
# ...         ...               ...               ...     ...
# 149643   149643  5369483464670140  5369483464670140       1
# 149673   149673  9622390651738378  9622390651738378       1
# 149726   149726  9608764640347533  9608764640347533       1
# 149806   149806  1342459325432779  1342459325432779       1
# 149839   149839  1720223228284859  1720223228284859       1
#
#                                                     title  \
# 379                   ...资产管理股份有限公司山东省分公司关于山东奥纳化工有限公司等...
# 662                        2020年3月26日裁定受理广州得者贸易有限公司破产清算一案
# 1213                      公牛集团上市10天市值突破1000亿 实控人身家已超过四川首富
# ...

# %%
news_unlabel_df = pd.read_csv('expand_news_l0.csv',sep='<-->', header=0, names=['onecomp_id', 'comp_name', 'title', 'news_date_format', 'content_merge'], error_bad_lines=False)
news_unlabel_df[['onecomp_id']] = news_unlabel_df[['onecomp_id']].astype(str)
news_unlabel_df['news_id'] = news_unlabel_df['onecomp_id'] + news_unlabel_df['title']  #'news_id' 唯一定位当前文本节点
news_unlabel_df['news_id'] = news_unlabel_df['news_id'].apply(lambda instr: get_hash_encode(instr))
news_unlabel_df = news_unlabel_df.rename(columns={'onecomp_id':'src_id', 'news_id':'dst_id'})
news_unlabel_df = news_unlabel_df.drop_duplicates(subset=['dst_id'],keep='first',inplace=False)
news_unlabel_edge = news_unlabel_df[['src_id', 'dst_id']]
news_unlabel_df['sentiment_label'] = -99
news_unlabel_df['multilabel'] = -99
# Out:
# /home/pai/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
news_merge_df = pd.concat((news_label_df[['src_id', 'dst_id', 'comp_name', 'title', 'content_merge','news_date_format', 'sentiment_label', 'multilabel']]
                           , news_unlabel_df[['src_id', 'dst_id', 'comp_name', 'title', 'content_merge','news_date_format', 'sentiment_label', 'multilabel']]), axis=0)


print(news_merge_df.shape)
news_merge_df = news_merge_df.loc[news_merge_df["dst_id"]!="5ee6a20881ee6401758945839e24f5fd"]
print(news_merge_df.shape)

news_merge_edge = news_merge_df[['src_id', 'dst_id']]
print(news_merge_edge)
# Out:
# (34941, 8)
# (34940, 8)
#                     src_id                            dst_id
# 0      1180716000048715115  3a9267138aa3839472b423e81e601882
# 1      1180716000048715115  d277b9b6cc3be4966cf54e01d26b3c7f
# 2      1180716000048715115  d7a0b365c4f3ce1f518f6f516fb09106
# 3      1180716000048715115  9aaa2dbdd89db7c47e2853ad6cbf1cf7
# 4      1180716000048715115  33b9422f60da341d9d21114deba6afe9
# ...                    ...                               ...
# 17426  1180716029859795517  d565600f0c1d441ffb9f36c10839d7ef
# 17427  1180716046950150079  ce1b34c0f2d8f823f641480694c20227
# 17429  1180716051916539270  00346c03a939f1d6863b8cc060de6359
# 17430  1180716010773284680  9a219428b6dd6e0a8d979b1fa36e1b95
# 17431  1180716013033744512  f304f9bbca77d6daa2c024d4f9d9018a
#
# [34940 rows x 2 columns]

# %%
edges_df = pd.concat([comp_edges, news_merge_edge], axis=0)#.sample(n=100)
# print(comp_edges.shape)
# print(edges_df.shape)

import pandas as pd
import networkx as nx
G_nx = nx.from_pandas_edgelist(edges_df, 'src_id', 'dst_id', edge_attr=True, create_using=nx.Graph())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-47332c9bb2c6> in <module>
# ----> 1 edges_df = pd.concat([comp_edges, news_merge_edge], axis=0)#.sample(n=100)
#       2 # print(comp_edges.shape)
#       3 # print(edges_df.shape)
#       4
#       5 import pandas as pd
#
# NameError: name 'pd' is not defined

# %%
node_idx_dict = {}
for idx, node in enumerate(G_nx.nodes()):
    node_idx_dict[idx] = node
#     G_nx.nodes[node]['node_id_ori'] = str(node)

node_idx_df = pd.DataFrame.from_dict(node_idx_dict, orient='index', columns= ["node_ori"])
node_idx_df = node_idx_df.reset_index().rename(columns = {'index':'node_id'})

node_feat_join_df = pd.merge(left=node_idx_df, right=news_merge_df, how='left', left_on='node_ori', right_on='dst_id')

# %%
print(node_feat_join_df)
print(len(G_nx.nodes()), node_idx_df.shape, node_feat_join_df.shape)
# Out:
#          node_id                          node_ori               src_id  \
# 0              0               1180716030490122867                  NaN
# 1              1  02021036086bfabbc84bc41375acdf05                  NaN
# 2              2               1180716044877810093                  NaN
# 3              3  0798a56a99c6943f8a5acb7e0e046f02                  NaN
# 4              4               1180716084568461957                  NaN
# ...          ...                               ...                  ...
# 5264420  5264420  d565600f0c1d441ffb9f36c10839d7ef  1180716029859795517
# 5264421  5264421  ce1b34c0f2d8f823f641480694c20227  1180716046950150079
# 5264422  5264422  00346c03a939f1d6863b8cc060de6359  1180716051916539270
# 5264423  5264423  9a219428b6dd6e0a8d979b1fa36e1b95  1180716010773284680
# 5264424  5264424  f304f9bbca77d6daa2c024d4f9d9018a  1180716013033744512
#
#                                    dst_id     comp_name  \
# ...

# %%
node_feat_join_df = node_feat_join_df.fillna("-")
node_feat_join_df.to_csv('ndatas/node_feat_join_merge.csv', sep='\t', index=0, columns=['node_id', 'node_ori', 'src_id', 'dst_id', 'comp_name', 'title','content_merge', 'news_date_format', 'sentiment_label', 'multilabel'])

# %%
sample_feat_df = node_feat_join_df[(node_feat_join_df["sentiment_label"]==0) | (node_feat_join_df["sentiment_label"]==1)]
sample_feat_df = sample_feat_df.sample(n=1000)
sample_feat_df.to_csv('ndatas/node_merge_sample.csv', sep='\t', index=0, columns=['node_id', 'node_ori', 'src_id', 'dst_id', 'comp_name', 'title','content_merge', 'news_date_format', 'sentiment_label', 'multilabel'])

# %%
dgl_graph_from_nx = dgl.from_networkx(G_nx)
save_graphs("dglgraphs/news_graph_from_nx_merge", [dgl_graph_from_nx])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-263f1522dae6> in <module>
# ----> 1 dgl_graph_from_nx = dgl.from_networkx(G_nx)
#       2 save_graphs("dglgraphs/news_graph_from_nx_merge", [dgl_graph_from_nx])
#
# /home/pai/lib/python3.6/site-packages/dgl/convert.py in from_networkx(nx_graph, node_attrs, edge_attrs, edge_id_attr_name, idtype, device)
#    1253
#    1254     # Relabel nodes using consecutive integers starting from 0
# -> 1255     nx_graph = nx.convert_node_labels_to_integers(nx_graph, ordering='sorted')
#    1256     if not nx_graph.is_directed():
#    1257         nx_graph = nx_graph.to_directed()
#
# /home/pai/lib/python3.6/site-packages/networkx/relabel.py in convert_node_labels_to_integers(G, first_label, ordering, label_attribute)
#     218     else:
#     219         raise nx.NetworkXError('Unknown node ordering: %s' % ordering)
# ...

# %%
glist,_ = load_graphs("dglgraphs/news_graph_from_nx_merge")
print("g.number_of_nodes():", glist[0].number_of_nodes())
print("g.number_of_edges():", glist[0].number_of_edges())
# Out:
# g.number_of_nodes(): 5264425
# g.number_of_edges(): 13922028

# %%
print(node_feat_join_df.columns)
print(node_feat_join_df)
# Out:
# Index(['node_id', 'node_ori', 'src_id', 'dst_id', 'comp_name', 'title',
#        'content_merge', 'news_date_format', 'sentiment_label', 'multilabel'],
#       dtype='object')
#          node_id                          node_ori               src_id  \
# 0              0               1180716030490122867                    -
# 1              1  02021036086bfabbc84bc41375acdf05                    -
# 2              2               1180716044877810093                    -
# 3              3  0798a56a99c6943f8a5acb7e0e046f02                    -
# 4              4               1180716084568461957                    -
# ...          ...                               ...                  ...
# 5264420  5264420  d565600f0c1d441ffb9f36c10839d7ef  1180716029859795517
# 5264421  5264421  ce1b34c0f2d8f823f641480694c20227  1180716046950150079
# 5264422  5264422  00346c03a939f1d6863b8cc060de6359  1180716051916539270
# 5264423  5264423  9a219428b6dd6e0a8d979b1fa36e1b95  1180716010773284680
# ...

# %%
g_nodes_list = G_nx.nodes()

print(g_nodes_list[1])
# def get_neigbors(G_nx, node, depth=1):
#     output = {}
#     layers = dict(nx.bfs_successors(G_nx, source=node, depth_limit=depth))
#     nodes = [node]
#     for i in range(1,depth+1):
#         output[i] = []
#         for x in nodes:
#             output[i].extend(layers.get(x,[]))
#         nodes = output[i]
#     return output

# nei_0 = get_neigbors(G_nx, 0)
# print(nei_0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-39d5df834f45> in <module>
# ----> 1 g_nodes_list = G_nx.nodes()
#       2
#       3 print(g_nodes_list[1])
#       4 # def get_neigbors(G_nx, node, depth=1):
#       5 #     output = {}
#
# NameError: name 'G_nx' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-913cc8ccdc27> in <module>
# ----> 1 print(new_df)
#
# NameError: name 'new_df' is not defined
